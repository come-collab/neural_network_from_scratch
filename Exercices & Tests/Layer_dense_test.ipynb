# %%
#Our hypothetic scenario is the following : 
#We have a neural network with one neuron as the input, a layer of 64 neurons so 64 weights
#and 1 output neuron with 64 neurons (from the previous) and 1 neurons output
#Lets code the layer Dense from scratch to understand
import numpy as np 

class Layer_Dense :

    def __init__(self,number_of_neurons,number_of_inputs):
        
        #[1 => [] 
        # 2 => []
        # 3 => []]
        #Un tableau de n_neuron ligne, avec n_weight value dans chaque tableau
        self.weights = 0.2 * np.random.normal(size=(number_of_neurons, number_of_inputs))
        self.biases = np.zeros((number_of_neurons,1))
        
    def forward(self,inputs):
        
        #To understand better how to understand : 
        print("shape of the weights : ", self.weights.shape)
        print("shape of the Input (we precised that it should be 1 so an array of 1 )" , np.array(inputs).shape)
        print("shape of the bias : " , self.biases.shape)
        print("What we want is for the input value to be multiplied with each neuron weight and stored in an array")
        self.output = np.dot(self.weights,inputs) + self.biases
        print("Here is the output : ", self.output)
    def backward():
        pass

#Here we define a layer of 64 neurons and 1 inputs
layer1 = Layer_Dense(64,1)
inputs = [[2.0]]
layer1.forward(inputs)

#here we define a layer of 1 neurons and 64 inputs (its the final output of our neural network)
layer2 = Layer_Dense(1,64)
layer2.forward(layer1.output)
# Out:
# shape of the weights :  (64, 1)
# shape of the Input (we precised that it should be 1 so an array of 1 ) (1, 1)
# shape of the bias :  (64, 1)
# What we want is for the input value to be multiplied with each neuron weight and stored in an array
# Here is the output :  [[ 0.09884093]
#  [-0.11956461]
#  [ 0.33448244]
#  [-0.82206133]
#  [-0.3719629 ]
#  [-0.67002953]
#  [ 0.67686991]
#  [-0.15331081]
#  [-0.64682455]
#  [-0.06627865]
#  [ 0.56715153]
#  [ 0.27933213]
#  [-0.28809294]
#  [ 0.1389952 ]
#  [ 0.21750437]
#  [ 0.28214963]
#  [-0.04436662]
#  [-0.15475958]
#  [ 0.19789047]
#  [ 0.21326339]
#  [-0.13131506]
#  [ 1.05079667]
#  [-0.49851619]
#  [ 0.49792319]
#  [-0.05941115]
#  [ 0.23226024]
#  [ 0.47579406]
#  [-0.36049774]
#  [ 0.19547935]
#  [ 0.39124193]
#  [ 0.35843846]
#  [-0.2426224 ]
#  [-0.00861495]
#  [-0.25047075]
#  [-0.08171162]
#  [-0.34056484]
#  [-0.20164037]
#  [-0.15405148]
#  [-0.22898228]
#  [-0.45283407]
#  [ 0.66323184]
#  [ 0.30269318]
#  [-0.11141612]
# ...
